# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from bs4 import BeautifulSoup
from tqdm.autonotebook import tqdm

porter=PorterStemmer()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\ipykernel_launcher.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
data = pd.read_pickle("./train.pkl")
data.head(10)
# Out:
#                                                 text  label
# 0  iranianbacked militia rout last syrian militan...      1
# 1  president obama late scapegoat obamacare implo...      0
# 2  song dynasty bowl shatters world record chines...      1
# 3  former dea prescription head drop bombshell co...      0
# 4  man barge woman bathroom saw shorthaired woman...      0
# 5  president donald trump schedule thursday septe...      0
# 6  wikileaks look clinton camp want please pinter...      0
# 7  (Reuters) - Voters in four U.S. cities will de...      1
# 8  trump want help u business lift slew regulatio...      1
# 9  ted cruz get own fox host whine tough question...      0

# %%
test_data = pd.read_pickle("./test.pkl")
test_data.head(10)
# Out:
#                                                 text  label
# 0  chicago bear versus green bay packer quick inj...      0
# 1  compromise reach iran talk washington cnn comp...      1
# 2  nyt trump supporter threaten violent revolutio...      0
# 3  jeff session rip bureaucrat refuse back trump ...      1
# 4  one picture describe failure republican party ...      0
# 5  u urge eu hopeful albania get tough big fish c...      1
# 6  south africa ramaphosa say party top six combi...      1
# 7  common painkiller link increased heart failure...      0
# 8  woman get death threat post picture hillary cl...      0
# 9  rig election hillary trump catch party kissing...      0

# %%
def replac(x):
  x=x.replace("$","dollar")
  x=x.replace("U.S.","United States")
  x=x.replace("U.K.","United Kingdom")
  x=x.replace("€","euro")
  x=x.replace("₹","rupee")
  x=x.replace("¥","yen")
  x=x.replace("£","pound")
  x=x.replace("%","percent")
  x=x.replace("&","and")
  x=x.replace("'ll"," will")
  x=x.replace(","," ")
  x=x.replace("?"," ")
  x=x.replace("i'm","i am")
  x=x.replace("'s"," is")
  x=x.replace("'ve"," have")
  x=x.replace("won't","will not")
  x=x.replace("can't","can not")
  x=x.replace("n't"," not")
  x=x.replace(",000","k")
  x=x.replace("000,000","m")
  x=x.replace("000,000,000","b")
  x=x.replace("."," ")
  return x;

def preprocessing(x):
  x=x.lower()
  x=replac(x)
  x=BeautifulSoup(x)
  x=x.get_text()
  lis=x.split()
  st=""
  for word in lis:
    st+=porter.stem(word)
    st+=" "
  x=st;
  return x;

# %%
tqdm.pandas()
data['text']=data['text'].progress_apply(preprocessing)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...

# %%
tqdm.pandas()
test_data['text']=test_data['text'].progress_apply(preprocessing)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...

# %%
import string

def punctuation_removal(text):
    all_list = [char for char in text if char not in string.punctuation]
    clean_str = ''.join(all_list)
    return clean_str

tqdm.pandas()
data['text'] = data['text'].progress_apply(punctuation_removal)
test_data['text']=test_data['text'].progress_apply(punctuation_removal)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')

data['text'] = data['text'].progress_apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
test_data['text'] = test_data['text'].progress_apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
data.to_pickle("preprocess_train.pkl")
test_data.to_pickle("preprocess_test.pkl")

# %%
data = pd.read_pickle("preprocess_train.pkl")
test_data = pd.read_pickle("preprocess_test.pkl")

# %%
print(data.groupby(['label'])['text'].count())
data.groupby(['label'])['text'].count().plot(kind="bar")
plt.show()
# Out:
# label
# 0    54276
# 1    52212
# Name: text, dtype: int64

# %%
from wordcloud import WordCloud

fake_data = data[data["label"] == 0]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud

real_data = data[data["label"] == 1]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from nltk import tokenize

token_space = tokenize.WhitespaceTokenizer()

def counter(text, column_text, quantity):
    all_words = ' '.join([text for text in text[column_text]])
    token_phrase = token_space.tokenize(all_words)
    frequency = nltk.FreqDist(token_phrase)
    df_frequency = pd.DataFrame({"Word": list(frequency.keys()),
                                   "Frequency": list(frequency.values())})
    df_frequency = df_frequency.nlargest(columns = "Frequency", n = quantity)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_frequency, x = "Word", y = "Frequency", color = 'blue')
    ax.set(ylabel = "Count")
    plt.xticks(rotation='vertical')
    plt.show()

# %%
counter(data[data["label"] == 0], "text", 20)

# %%
counter(data[data["label"] == 1], "text", 20)

# %%
from sklearn import metrics
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
X_train = data["text"]
X_test = test_data["text"]
y_train = data["label"]
y_test = test_data["label"]

# %%
dct = dict()

from sklearn.naive_bayes import MultinomialNB

NB_classifier = MultinomialNB()
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', NB_classifier)])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))

dct['Naive Bayes'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 87.09%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LogisticRegression())])

# Fitting the model
model = pipe.fit(X_train, y_train)

# Accuracy
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Logistic Regression'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# accuracy: 96.98%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.tree import DecisionTreeClassifier

# Vectorizing and applying TF-IDF
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', DecisionTreeClassifier(criterion= 'entropy',
                                           max_depth = 5, 
                                           splitter='best', 
                                           random_state=42))])
# Fitting the model
model = pipe.fit(X_train, y_train)

# Accuracy
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Decision Tree'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 87.82%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', RandomForestClassifier(n_estimators=3, criterion="entropy"))])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Random Forest'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.67%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', clf)])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['SVM'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.1%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization
