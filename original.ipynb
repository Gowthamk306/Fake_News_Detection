# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\python\python310\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\python\python310\lib\site-packages (from wordcloud) (1.22.3)
# Requirement already satisfied: pillow in c:\python\python310\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\python\python310\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.31.2)
# Requirement already satisfied: cycler>=0.10 in c:\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\python\python310\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\python\python310\lib\site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python310\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\python\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\python\python310\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy>=1.15 in c:\python\python310\lib\site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: scipy>=1.0 in c:\python\python310\lib\site-packages (from seaborn) (1.8.0)
# Requirement already satisfied: pandas>=0.23 in c:\python\python310\lib\site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.31.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\python\python310\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.22.3)
# Requirement already satisfied: joblib>=0.11 in c:\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.8.0)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\python\python310\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\python\python310\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: joblib in c:\python\python310\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\python\python310\lib\site-packages (from nltk) (8.1.0)
# Requirement already satisfied: tqdm in c:\python\python310\lib\site-packages (from nltk) (4.63.1)
# Requirement already satisfied: colorama in c:\python\python310\lib\site-packages (from click->nltk) (0.4.4)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
fake = pd.read_csv("C:/Users/RITEESH/Desktop/LBP/data/Fake.csv")
true = pd.read_csv("C:/Users/RITEESH/Desktop/LBP/data/True.csv")

# %%
fake.shape
# Out:
# (23481, 4)

# %%
true.shape
# Out:
# (21417, 4)

# %%
fake['target'] = 'fake'
true['target'] = 'true'

# %%
data = pd.concat([fake, true]).reset_index(drop = True)
data.shape
# Out:
# (44898, 5)

# %%
from sklearn.utils import shuffle
data = shuffle(data)
data = data.reset_index(drop=True)

# %%
data.drop(["date"],axis=1,inplace=True)
data.head()
# Out:
#                                                title  \
# 0  South Korea's Moon says cannot recognize North...
# 1  DALLAS RALLY VIDEO: Trump Lets It Rip On The “...
# 2   President Obama Tells Audience Why Americans ...
# 3   Trump Caught Illegally Buying $55,000 Worth O...
# 4  BREAKING: Oregon Armed Militia Holding Federal...
#
#                                                 text          subject target
# 0  SEOUL/BEIJING (Reuters) - South Korea will nev...        worldnews   true
# 1  The truth hurts and Trump has no problem deliv...         politics   fake
# 2  President Obama took a trip to Milan, Italy th...             News   fake
# 3  Donald Trump has been caught buying $55,000 wo...             News   fake
# 4  OREGON RANCHERS TAKE A STAND: The feds felt a ...  Government News   fake

# %%
data.drop(["title"],axis=1,inplace=True)
data.head()
# Out:
#                                                 text          subject target
# 0  SEOUL/BEIJING (Reuters) - South Korea will nev...        worldnews   true
# 1  The truth hurts and Trump has no problem deliv...         politics   fake
# 2  President Obama took a trip to Milan, Italy th...             News   fake
# 3  Donald Trump has been caught buying $55,000 wo...             News   fake
# 4  OREGON RANCHERS TAKE A STAND: The feds felt a ...  Government News   fake

# %%
data['text'] = data['text'].apply(lambda x: x.lower())
data.head()
# Out:
#                                                 text          subject target
# 0  seoul/beijing (reuters) - south korea will nev...        worldnews   true
# 1  the truth hurts and trump has no problem deliv...         politics   fake
# 2  president obama took a trip to milan, italy th...             News   fake
# 3  donald trump has been caught buying $55,000 wo...             News   fake
# 4  oregon ranchers take a stand: the feds felt a ...  Government News   fake

# %%
import string

def punctuation_removal(text):
    all_list = [char for char in text if char not in string.punctuation]
    clean_str = ''.join(all_list)
    return clean_str

data['text'] = data['text'].apply(punctuation_removal)
data.head()
# Out:
#                                                 text          subject target
# 0  seoulbeijing reuters  south korea will never t...        worldnews   true
# 1  the truth hurts and trump has no problem deliv...         politics   fake
# 2  president obama took a trip to milan italy thi...             News   fake
# 3  donald trump has been caught buying 55000 wort...             News   fake
# 4  oregon ranchers take a stand the feds felt a r...  Government News   fake

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')

data['text'] = data['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\RITEESH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(data.groupby(['subject'])['text'].count())
data.groupby(['subject'])['text'].count().plot(kind="bar")
plt.show()
# Out:
# subject
# Government News     1570
# Middle-east          778
# News                9050
# US_News              783
# left-news           4459
# politics            6841
# politicsNews       11272
# worldnews          10145
# Name: text, dtype: int64

# %%
print(data.groupby(['target'])['text'].count())
data.groupby(['target'])['text'].count().plot(kind="bar")
plt.show()
# Out:
# target
# fake    23481
# true    21417
# Name: text, dtype: int64

# %%
from wordcloud import WordCloud

fake_data = data[data["target"] == "fake"]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud

real_data = data[data["target"] == "true"]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from nltk import tokenize

token_space = tokenize.WhitespaceTokenizer()

def counter(text, column_text, quantity):
    all_words = ' '.join([text for text in text[column_text]])
    token_phrase = token_space.tokenize(all_words)
    frequency = nltk.FreqDist(token_phrase)
    df_frequency = pd.DataFrame({"Word": list(frequency.keys()),
                                   "Frequency": list(frequency.values())})
    df_frequency = df_frequency.nlargest(columns = "Frequency", n = quantity)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_frequency, x = "Word", y = "Frequency", color = 'blue')
    ax.set(ylabel = "Count")
    plt.xticks(rotation='vertical')
    plt.show()

# %%
counter(data[data["target"] == "fake"], "text", 20)

# %%
counter(data[data["target"] == "true"], "text", 20)

# %%
from sklearn import metrics
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
X_train,X_test,y_train,y_test = train_test_split(data['text'], data.target, test_size=0.2, random_state=42)

# %%
dct = dict()

from sklearn.naive_bayes import MultinomialNB

NB_classifier = MultinomialNB()
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', NB_classifier)])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))

dct['Naive Bayes'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 94.9%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LogisticRegression())])

# Fitting the model
model = pipe.fit(X_train, y_train)

# Accuracy
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Logistic Regression'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.02%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.tree import DecisionTreeClassifier

# Vectorizing and applying TF-IDF
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', DecisionTreeClassifier(criterion= 'entropy',
                                           max_depth = 20, 
                                           splitter='best', 
                                           random_state=42))])
# Fitting the model
model = pipe.fit(X_train, y_train)

# Accuracy
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Decision Tree'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.6%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', RandomForestClassifier(n_estimators=50, criterion="entropy"))])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Random Forest'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.21%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', clf)])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['SVM'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.71%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,7))
plt.bar(list(dct.keys()),list(dct.values()))
plt.ylim(90,100)
plt.yticks((91, 91.5, 92, 92.5, 93, 93.5, 94, 94.5, 95, 95.5, 96, 96.5, 97, 97.5, 98, 98.5, 99, 99.5, 100))
# Out:
# ([<matplotlib.axis.YTick at 0x27e28b2f280>,
#   <matplotlib.axis.YTick at 0x27e28b2eb00>,
#   <matplotlib.axis.YTick at 0x27e28b2db10>,
#   <matplotlib.axis.YTick at 0x27e27d136a0>,
#   <matplotlib.axis.YTick at 0x27e27d13df0>,
#   <matplotlib.axis.YTick at 0x27e27d13a90>,
#   <matplotlib.axis.YTick at 0x27e2764c730>,
#   <matplotlib.axis.YTick at 0x27e2764ce80>,
#   <matplotlib.axis.YTick at 0x27e2764d5d0>,
#   <matplotlib.axis.YTick at 0x27e2764dd20>,
#   <matplotlib.axis.YTick at 0x27e2764e470>,
#   <matplotlib.axis.YTick at 0x27e27d13760>,
#   <matplotlib.axis.YTick at 0x27e2764dc90>,
#   <matplotlib.axis.YTick at 0x27e2764c9a0>,
#   <matplotlib.axis.YTick at 0x27e2764f160>,
#   <matplotlib.axis.YTick at 0x27e2764f8b0>,
#   <matplotlib.axis.YTick at 0x27e277a0040>,
#   <matplotlib.axis.YTick at 0x27e277a0790>,
#   <matplotlib.axis.YTick at 0x27e2764f820>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
